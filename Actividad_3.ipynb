# %%
import pandas as pd
print(f"version de pandas: {pd.__version__}")
# Out:
# version de pandas: 2.2.2

# %%
## leer archivo excel
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
archivo = pd.read_excel("/content/drive/MyDrive/LIQUIDACION NOMINA lorena.xlsx",sheet_name="Liquidación Horas Extras",header=1)
archivo
# Out:
#                   NOMBRE DEL EMPLEADO  CODIGO CARGO  SALARIO ASIGNADO  \
# 0               ACERO LOZANO GERARDO              7           3250000
# 1    ALARCÓN GONZALEZ DIGNAEL AUGUSTO             7           3250000
# 2       ARIAS MALDONADO MARTHA ISABEL             5           2650000
# 3           AVILA PERDOMO LUZ BIBIANA             9           6000000
# 4            YOPASA CAMACHO MAURICIO              4           2450000
# ..                                ...           ...               ...
# 168     ACOSTA GONZALEZ OSCAR ENRIQUE             2           1626000
# 169         ARIZA PEÑA WILLIAM HERNAN             4           2450000
# 170        ACUÑA CORDERO FANNY LUCERO             5           2650000
# 171        ALVAREZ ALVAREZ ALBA LUCIA             6           3500000
# 172            ACERO LÒPEZ YURY PAOLA             7           3500000
#
#      N° HORAS EXTRAS DIURNAS TRABAJADAS  \
# 0                                    29
# 1                                    13
# ...

# %%
### ACTIVIDAD 3
archivo.shape
# Out:
# (173, 15)

# %%
archivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 15 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   NOMBRE DEL EMPLEADO                                        173 non-null    object
#  1   CODIGO CARGO                                               173 non-null    int64
#  2   SALARIO ASIGNADO                                           173 non-null    int64
#  3   N° HORAS EXTRAS DIURNAS TRABAJADAS                         173 non-null    int64
#  4   VALOR HORAS EXTRAS DIURNAS TRABAJADAS                      173 non-null    float64
#  5   N° HORAS EXTRAS NOCTURNAS TRABAJADAS                       173 non-null    int64
#  6   VALOR HORAS EXTRAS NOCTURNAS TRABAJADAS                    173 non-null    float64
#  7   N° HORAS EXTRAS DOM-FESTIVAS DIURNAS TRABAJADAS            173 non-null    int64
# ...

# %%
archivo.describe()
# Out:
#        CODIGO CARGO  SALARIO ASIGNADO  N° HORAS EXTRAS DIURNAS TRABAJADAS  \
# count    173.000000      1.730000e+02                          173.000000
# mean       4.560694      2.560566e+06                           15.069364
# std        2.433550      9.147385e+05                            9.431876
# min        1.000000      1.423500e+06                            0.000000
# 25%        2.000000      1.626000e+06                            6.000000
# 50%        5.000000      2.650000e+06                           15.000000
# 75%        7.000000      3.250000e+06                           24.000000
# max       10.000000      6.500000e+06                           30.000000
#
#        VALOR HORAS EXTRAS DIURNAS TRABAJADAS  \
# count                             173.000000
# mean                           213686.449028
# std                            151263.389026
# min                                 0.000000
# 25%                             92329.545455
# ...

# %%
archivo_filtrado = archivo[archivo['CODIGO CARGO']==7]
archivo_filtrado
# Out:
#                       NOMBRE DEL EMPLEADO  CODIGO CARGO  SALARIO ASIGNADO  \
# 0                   ACERO LOZANO GERARDO              7           3250000
# 1        ALARCÓN GONZALEZ DIGNAEL AUGUSTO             7           3250000
# 7             CAÑON HERNANDEZ DEICY ROCIO             7           3250000
# 10     CARVAJAL ARISTIZABAL JORGE ENRIQUE             7           3250000
# 12   CASTELLANOS CORTES LILIANA ALEXANDRA             7           3250000
# 13        CASTELLANOS ANGULO MIGUEL ANGEL             7           3250000
# 35                   NIÑO LEDESMA ELISEO              7           3250000
# 45                BALLEN PAJARITO ANDRES              7           3250000
# 46             TORREJANO PALOMARES NANCY              7           3250000
# 65            RUIZ CORREDOR LUIS HERNANDO             7           3250000
# 68                    CRUZ SUAREZ JOHANA              7           3250000
# 89            SANCHEZ CALA SANDRA MARCELA             7           3250000
# ...

# %%
archivo.sort_values(by='CODIGO CARGO',ascending=False)
# Out:
#                      NOMBRE DEL EMPLEADO  CODIGO CARGO  SALARIO ASIGNADO  \
# 28        GONZÁLEZ GARCIA SERGIO ANTONIO            10           6500000
# 3              AVILA PERDOMO LUZ BIBIANA             9           6000000
# 29   GUARNIZO VALENZUELA SANDRA PATRICIA             8           3900000
# 17              DIAZ ALVAREZ JOHN HARVYN             8           3900000
# 27             HOYOS GONZÁLEZ KATHERINE              8           3900000
# ..                                   ...           ...               ...
# 148             GUZMAN RODRIGUEZ SANDRA              1           1423500
# 143               CHOACHI RAMIREZ JULIO              1           1423500
# 162               APARICIO MEJIA YANETH              1           1423500
# 163         ABELLO FORERO CLAUDIA MILENA             1           1423500
# 166               ACOSTA PINEDA GUSTAVO              1           1423500
#
#      N° HORAS EXTRAS DIURNAS TRABAJADAS  \
# 28                                    6
# ...
